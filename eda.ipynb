# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("behzadhassan/sympscan-symptomps-to-disease")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.08M/1.08M [00:01<00:00, 899kB/s]
# Extracting files...
# Path to dataset files: C:\Users\chips\.cache\kagglehub\datasets\behzadhassan\sympscan-symptomps-to-disease\versions\1

# %%
1+1
# Out:
# 2
